# %% [markdown]
# - Creating arrays from real-world data (e.g., simulated sensor readings, financial data)
# - Statistical analysis (mean, median, std, percentiles)
# - Data normalization and scaling
# - Random sampling and simulation
# - Matrix operations (correlation, covariance)
# - Element-wise operations and masking
# - Aggregation and grouping

# %% [markdown]
# An array is a data structure that stores a collection of elements, usually numbers. Arrays can look similar to lists, but they are designed for numerical work. All elements in an array must be the same type, which makes arrays faster and more efficient for calculations than lists.

# %%
# %pip install numpy

import numpy as np
print("NumPy version:", np.__version__)
# Out:
# NumPy version: 2.4.1

# %%
# Creating arrays
arr = np.array([1, 2, 3, 4])
arr2 = np.array([10, 20, 30, 40])
print("Array:", arr)
print("First element:", arr[0])
print("Slice:", arr[1:3])
print("Mean:", np.mean(arr))
print("Min:", np.min(arr))
print("Max:", np.max(arr))
print("Sum:", arr + arr2)
# Out:
# Array: [1 2 3 4]
# First element: 1
# Slice: [2 3]
# Mean: 2.5
# Min: 1
# Max: 4
# Sum: [11 22 33 44]
